# %% [markdown]
# <a href="https://colab.research.google.com/github/mondweep/vibe-cast/blob/ad-hoc-tinkering/example_notebooks/kfinance_basic_usage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### Copyright 2025 Kensho Technologies, LLC

# %% [markdown]
# # LLM-ready API Basic Usage (without a large language model)
# **_Call the LLM-ready API using the kFinance python library!_**
#
# To run this notebook, you'll need kFinance credentials.
#
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/kensho-technologies/kfinance/blob/main/example_notebooks/basic_usage.ipynb"><img src="https://github.com/kensho-technologies/kfinance/blob/main/images/colab_logo_32px.png?raw=1" />Run in Google Colab</a>
#   </td>
# </table>

# %% [markdown]
# # Install Dependencies

# %%
# install the latest version of kFinance package
# %pip install kensho-kfinance
# Out:
# Requirement already satisfied: kensho-kfinance in /usr/local/lib/python3.12/dist-packages (4.1.1)
# Requirement already satisfied: cachetools<7,>=6 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (6.2.4)
# Requirement already satisfied: click<=9,>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (8.3.1)
# Requirement already satisfied: fastmcp<2.14,>=2.13.1 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (2.13.3)
# Requirement already satisfied: langchain-core>=0.3.15 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (1.2.6)
# Requirement already satisfied: langchain-google-genai<3,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (2.1.12)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (2.0.2)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (2.2.2)
# Requirement already satisfied: pillow>=10 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (11.3.0)
# Requirement already satisfied: pydantic<3,>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (2.12.3)
# Requirement already satisfied: pyjwt>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (2.10.1)
# Requirement already satisfied: python-dateutil<2.9,>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (2.8.2)
# Requirement already satisfied: strenum>=0.4.15 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (0.4.15)
# Requirement already satisfied: tabulate>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (0.9.0)
# Requirement already satisfied: types-requests<3,>=2.22.0 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (2.32.4.20260107)
# Requirement already satisfied: requests<3,>=2.22.0 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (2.32.4)
# Requirement already satisfied: urllib3>=2.5 in /usr/local/lib/python3.12/dist-packages (from kensho-kfinance) (2.5.0)
# Requirement already satisfied: authlib>=1.6.5 in /usr/local/lib/python3.12/dist-packages (from fastmcp<2.14,>=2.13.1->kensho-kfinance) (1.6.6)
# Requirement already satisfied: cyclopts>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp<2.14,>=2.13.1->kensho-kfinance) (4.4.6)
# Requirement already satisfied: exceptiongroup>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from fastmcp<2.14,>=2.13.1->kensho-kfinance) (1.3.1)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.28.1)
# Requirement already satisfied: jsonschema-path>=0.3.4 in /usr/local/lib/python3.12/dist-packages (from fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.3.4)
# Requirement already satisfied: mcp!=1.21.1,<1.23,>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp<2.14,>=2.13.1->kensho-kfinance) (1.22.0)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.5.1)
# Requirement already satisfied: platformdirs>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp<2.14,>=2.13.1->kensho-kfinance) (4.5.1)
# Requirement already satisfied: py-key-value-aio<0.4.0,>=0.2.8 in /usr/local/lib/python3.12/dist-packages (from py-key-value-aio[disk,memory]<0.4.0,>=0.2.8->fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.3.0)
# Requirement already satisfied: pyperclip>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp<2.14,>=2.13.1->kensho-kfinance) (1.11.0)
# Requirement already satisfied: python-dotenv>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from fastmcp<2.14,>=2.13.1->kensho-kfinance) (1.2.1)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.12/dist-packages (from fastmcp<2.14,>=2.13.1->kensho-kfinance) (13.9.4)
# Requirement already satisfied: uvicorn>=0.35 in /usr/local/lib/python3.12/dist-packages (from fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.40.0)
# Requirement already satisfied: websockets>=15.0.1 in /usr/local/lib/python3.12/dist-packages (from fastmcp<2.14,>=2.13.1->kensho-kfinance) (15.0.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.15->kensho-kfinance) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.15->kensho-kfinance) (0.6.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.15->kensho-kfinance) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.15->kensho-kfinance) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.15->kensho-kfinance) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.15->kensho-kfinance) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.3.15->kensho-kfinance) (0.13.0)
# Requirement already satisfied: google-ai-generativelanguage<1,>=0.7 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai<3,>=2.1.5->kensho-kfinance) (0.10.0)
# Requirement already satisfied: filetype<2,>=1.2 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai<3,>=2.1.5->kensho-kfinance) (1.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->kensho-kfinance) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->kensho-kfinance) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.10.0->kensho-kfinance) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.10.0->kensho-kfinance) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.10.0->kensho-kfinance) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<2.9,>=2.8.2->kensho-kfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.22.0->kensho-kfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.22.0->kensho-kfinance) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.22.0->kensho-kfinance) (2026.1.4)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from authlib>=1.6.5->fastmcp<2.14,>=2.13.1->kensho-kfinance) (43.0.3)
# Requirement already satisfied: attrs>=23.1.0 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=4.0.0->fastmcp<2.14,>=2.13.1->kensho-kfinance) (25.4.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=4.0.0->fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from cyclopts>=4.0.0->fastmcp<2.14,>=2.13.1->kensho-kfinance) (1.3.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1,>=0.7->langchain-google-genai<3,>=2.1.5->kensho-kfinance) (2.29.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1,>=0.7->langchain-google-genai<3,>=2.1.5->kensho-kfinance) (2.43.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1,>=0.7->langchain-google-genai<3,>=2.1.5->kensho-kfinance) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1,>=0.7->langchain-google-genai<3,>=2.1.5->kensho-kfinance) (1.27.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1,>=0.7->langchain-google-genai<3,>=2.1.5->kensho-kfinance) (5.29.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->fastmcp<2.14,>=2.13.1->kensho-kfinance) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->fastmcp<2.14,>=2.13.1->kensho-kfinance) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.28.1->fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.3.15->kensho-kfinance) (3.0.0)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema-path>=0.3.4->fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.4.4)
# Requirement already satisfied: referencing<0.37.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema-path>=0.3.4->fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.36.2)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.15->kensho-kfinance) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.15->kensho-kfinance) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.15->kensho-kfinance) (0.25.0)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp!=1.21.1,<1.23,>=1.19.0->fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from mcp!=1.21.1,<1.23,>=1.19.0->fastmcp<2.14,>=2.13.1->kensho-kfinance) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/lib/python3.12/dist-packages (from mcp!=1.21.1,<1.23,>=1.19.0->fastmcp<2.14,>=2.13.1->kensho-kfinance) (2.12.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp!=1.21.1,<1.23,>=1.19.0->fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.0.21)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp!=1.21.1,<1.23,>=1.19.0->fastmcp<2.14,>=2.13.1->kensho-kfinance) (3.1.2)
# Requirement already satisfied: starlette>=0.27 in /usr/local/lib/python3.12/dist-packages (from mcp!=1.21.1,<1.23,>=1.19.0->fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.50.0)
# Requirement already satisfied: py-key-value-shared==0.3.0 in /usr/local/lib/python3.12/dist-packages (from py-key-value-aio<0.4.0,>=0.2.8->py-key-value-aio[disk,memory]<0.4.0,>=0.2.8->fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.3.0)
# Requirement already satisfied: beartype>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from py-key-value-aio<0.4.0,>=0.2.8->py-key-value-aio[disk,memory]<0.4.0,>=0.2.8->fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.22.9)
# Requirement already satisfied: diskcache>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from py-key-value-aio[disk,memory]<0.4.0,>=0.2.8->fastmcp<2.14,>=2.13.1->kensho-kfinance) (5.6.3)
# Requirement already satisfied: pathvalidate>=3.3.1 in /usr/local/lib/python3.12/dist-packages (from py-key-value-aio[disk,memory]<0.4.0,>=0.2.8->fastmcp<2.14,>=2.13.1->kensho-kfinance) (3.3.1)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pydantic[email]>=2.11.7->fastmcp<2.14,>=2.13.1->kensho-kfinance) (2.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->fastmcp<2.14,>=2.13.1->kensho-kfinance) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->fastmcp<2.14,>=2.13.1->kensho-kfinance) (2.19.2)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp<2.14,>=2.13.1->kensho-kfinance) (2.8.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1,>=0.7->langchain-google-genai<3,>=2.1.5->kensho-kfinance) (1.72.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1,>=0.7->langchain-google-genai<3,>=2.1.5->kensho-kfinance) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1,>=0.7->langchain-google-genai<3,>=2.1.5->kensho-kfinance) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1,>=0.7->langchain-google-genai<3,>=2.1.5->kensho-kfinance) (4.9.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp!=1.21.1,<1.23,>=1.19.0->fastmcp<2.14,>=2.13.1->kensho-kfinance) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp!=1.21.1,<1.23,>=1.19.0->fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.30.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.1.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->authlib>=1.6.5->fastmcp<2.14,>=2.13.1->kensho-kfinance) (2.0.0)
# Requirement already satisfied: docutils in /usr/local/lib/python3.12/dist-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=4.0.0->fastmcp<2.14,>=2.13.1->kensho-kfinance) (0.21.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->authlib>=1.6.5->fastmcp<2.14,>=2.13.1->kensho-kfinance) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1,>=0.7->langchain-google-genai<3,>=2.1.5->kensho-kfinance) (0.6.1)

# %% [markdown]
# # Instantiate kFinance Client

# %%
# import the kfinance client
from kfinance.client.kfinance import Client

# import standard libraries
import functools
import types
import json
import sys
# check if the current environment is a Google Colab
try:
  import google.colab
  IN_GOOGLE_COLAB = True
except:
  IN_GOOGLE_COLAB = False

# initialize the kfinance client with one of the following:
# 1. your kensho refresh token
# 2. your kensho client id and kensho private key.
#       you can fetch your refresh token from https://kfinance.kensho.com/manual_login/
# 3. automated login (not accessible on Google Collab)
if IN_GOOGLE_COLAB:
    kensho_refresh_token = ""
    assert kensho_refresh_token != "", "kensho refresh token is empty! Make sure to enter your kensho refresh token above"
    kfinance_client = Client(refresh_token=kensho_refresh_token)
else:
    kfinance_client = Client()

# %% [markdown]
# ## Example functions

# %%
# You can create a Ticker object with client.ticker.
# A Ticker has access to a wide variety of attributes, including prices,
# market caps, statements, and line items.
spgi = kfinance_client.ticker("SPGI")

# %%
# To access some basic information like name, industry type, or number of employees
# about the company to which the ticker belongs, you can use the `info` attribute.
spgi.info

# %% [markdown]
# ### Statements and Line Items

# %%
# Kfinance can also provide you with access to statements and line items.
# The available statements are:
# - balance sheets (`.balance_sheet()`)
# - income statement (`.income_statement()`)
# - cash flow statement (`.cash_flow()`)
# Kfinance function can usually be invoked with no or minimal params.
# In those cases, defaults are used. For the statement and line item
# functions, for example, ...
spgi.balance_sheet()

# %%
from kfinance.client.models.date_and_period_models import PeriodType

# However, it's also possible to set parameters to fetch,
# for example, annual balance sheets from the 2010s.
spgi.balance_sheet(period_type=PeriodType.annual, start_year=2010, end_year=2019)

# %%
# Note that the templating for the sheets differs by industry.
# For example, JPM's balance sheet will contain different rows
# than SPGI's.
kfinance_client.ticker("JPM").balance_sheet()

# %%
# In addition to full sheets, you can also fetch individual line items
# like Cash And Equivalents (`.cash_and_cash_equivalents()`), or
# Net Income (`.net_income()).
# For a full list of available line items, see the `LINE_ITEMS` list in
# constants.py: https://github.com/kensho-technologies/kfinance/blob/9ec83b4fc77386df84de669269b55148fed85b94/kfinance/constants.py#L139
spgi.net_income(  # type: ignore[attr-defined]
    period_type=PeriodType.annual,
    start_year=2010,
    end_year=2019
)

# %% [markdown]
# ### Prices

# %%
# To fetch recent spgi prices, you can use the `history` function.
# This will return the last year of daily prices as a pandas DataFrame.
spgi.history()

# %%
from kfinance.client.models.date_and_period_models import Periodicity

# To fetch recent spgi prices, you can use the `history` function.
# Without any further configuration `history()` will return adjusted
# daily prices for the last year. However, it's possible to configure all
# of these params as needed, for example to fetch unadjusted monthly prices
# for the 2010s.
spgi.history(
    periodicity=Periodicity.month,
    adjusted=False,
    start_date="2010-01-01",
    end_date="2019-12-31"
)

# %%
# In addition to fetching prices as a pandas DataFrame, it's also possible
# to fetch prices as a chart with the `price_chart` function, which can take
# the same parameters as `history`.
spgi.price_chart(
    periodicity=Periodicity.month,
    adjusted=False,
    start_date="2010-01-01",
    end_date="2019-12-31"
)

# %%
# Beyond stock prices, it's also possible to fetch a company's
# market cap (`.market_cap`), total enterprise value (`.tev`), and
# number of shares outstanding (`.shares_outstanding`).
# Similar to `history`, this will return a DataFrame of daily prices.
# spgi.market_cap()
